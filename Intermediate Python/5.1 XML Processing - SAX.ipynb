# %% [markdown]
# # 5.1 XML Processing

# %% [markdown]
# SQL databases are useful for storing large amounts of data. However, sometimes we want to store data in a less complicated data structure. This is useful as a format for **data interchange**. For example, we have already seen how JSON can do this since it is independent of programming language and platform. XML (Extensible Markup Language) is another such data format. There are two librarys for working with XML in the PSL called **SAX** and **DOM**. Starting with the SAX module,

# %%
import xml.sax

# %% [markdown]
# SAX is useful for when we are dealing with large XML files and/or we want to use a limit amount of RAM. We also cannot modify XML, but only read it.

# %%
class Handler(xml.sax.ContentHandler):
    """We must create our own handler which executues our desired code when the SAX
    parser parses an XML tag. In doing so, we must override existing methods."""

    def startElement(self, name, attrs):
        """The startElement method is called when the starting tag of an element is parsed.
        Here, we are overriding it with our own code."""
        
        print(f"Opening Tag: {name}")

    def endElement(self, name):
        """The endElement method is called when the end tag of an element is parsed. Here,
        we are overriding it with our own code."""
        print(f"Closing Tag: {name}")

    def characters(self, content):
        print(f"Content: {content}")

# We create our handler object,
handler = Handler()

# Then we create our SAX parser and set its handler,
parser = xml.sax.make_parser()
parser.setContentHandler(handler)

# Finally, we must called the parse() method to begin parsing the XML file,
parser.parse("books.xml")
# Out:
# Opening Tag: catalog
# Content:
#
# Content:
# Opening Tag: book
# Content:
#
# Content:
# Opening Tag: author
# Content: Gambardella, Matthew
# CLosing Tag: author
# Content:
#
# Content:
# Opening Tag: title
# Content: XML Developer's Guide
# CLosing Tag: title
# Content:
#
# Content:
# Opening Tag: genre
# Content: Computer
# CLosing Tag: genre
# Content:
#
# Content:
# Opening Tag: price
# Content: 44.95
# CLosing Tag: price
# Content:
#
# Content:
# Opening Tag: publish_date
# Content: 2000-10-01
# CLosing Tag: publish_date
# Content:
#
# Content:
# Opening Tag: description
# Content: An in-depth look at creating applications
# Content:
#
# Content:       with XML.
# CLosing Tag: description
# Content:
#
# Content:
# CLosing Tag: book
# Content:
#
# Content:
# Opening Tag: book
# Content:
#
# Content:
# Opening Tag: author
# Content: Ralls, Kim
# CLosing Tag: author
# Content:
#
# Content:
# Opening Tag: title
# Content: Midnight Rain
# CLosing Tag: title
# Content:
#
# Content:
# Opening Tag: genre
# Content: Fantasy
# CLosing Tag: genre
# Content:
#
# Content:
# Opening Tag: price
# Content: 5.95
# CLosing Tag: price
# Content:
#
# Content:
# Opening Tag: publish_date
# Content: 2000-12-16
# CLosing Tag: publish_date
# Content:
#
# Content:
# Opening Tag: description
# Content: A former architect battles corporate zombies,
# Content:
#
# Content:       an evil sorceress, and her own childhood to become queen
# Content:
#
# Content:       of the world.
# CLosing Tag: description
# Content:
#
# Content:
# CLosing Tag: book
# Content:
#
# Content:
# Opening Tag: book
# Content:
#
# Content:
# Opening Tag: author
# Content: Corets, Eva
# CLosing Tag: author
# Content:
#
# Content:
# Opening Tag: title
# Content: Maeve Ascendant
# CLosing Tag: title
# Content:
#
# Content:
# Opening Tag: genre
# Content: Fantasy
# CLosing Tag: genre
# Content:
#
# Content:
# Opening Tag: price
# Content: 5.95
# CLosing Tag: price
# Content:
#
# Content:
# Opening Tag: publish_date
# Content: 2000-11-17
# CLosing Tag: publish_date
# Content:
#
# Content:
# Opening Tag: description
# Content: After the collapse of a nanotechnology
# Content:
#
# Content:       society in England, the young survivors lay the
# Content:
#
# Content:       foundation for a new society.
# CLosing Tag: description
# Content:
#
# Content:
# CLosing Tag: book
# Content:
#
# Content:
# Opening Tag: book
# Content:
#
# Content:
# Opening Tag: author
# Content: Corets, Eva
# CLosing Tag: author
# Content:
#
# Content:
# Opening Tag: title
# Content: Oberon's Legacy
# CLosing Tag: title
# Content:
#
# Content:
# Opening Tag: genre
# Content: Fantasy
# CLosing Tag: genre
# Content:
#
# Content:
# Opening Tag: price
# Content: 5.95
# CLosing Tag: price
# Content:
#
# Content:
# Opening Tag: publish_date
# Content: 2001-03-10
# CLosing Tag: publish_date
# Content:
#
# Content:
# Opening Tag: description
# Content: In post-apocalypse England, the mysterious
# Content:
#
# Content:       agent known only as Oberon helps to create a new life
# Content:
#
# Content:       for the inhabitants of London. Sequel to Maeve
# Content:
#
# Content:       Ascendant.
# CLosing Tag: description
# Content:
#
# Content:
# CLosing Tag: book
# Content:
#
# Content:
# Opening Tag: book
# Content:
#
# Content:
# Opening Tag: author
# Content: Corets, Eva
# CLosing Tag: author
# Content:
#
# Content:
# Opening Tag: title
# Content: The Sundered Grail
# CLosing Tag: title
# Content:
#
# Content:
# Opening Tag: genre
# Content: Fantasy
# CLosing Tag: genre
# Content:
#
# Content:
# Opening Tag: price
# Content: 5.95
# CLosing Tag: price
# Content:
#
# Content:
# Opening Tag: publish_date
# Content: 2001-09-10
# CLosing Tag: publish_date
# Content:
#
# Content:
# Opening Tag: description
# Content: The two daughters of Maeve, half-sisters,
# Content:
#
# Content:       battle one another for control of England. Sequel to
# Content:
#
# Content:       Oberon's Legacy.
# CLosing Tag: description
# Content:
#
# Content:
# CLosing Tag: book
# Content:
#
# Content:
# Opening Tag: book
# Content:
#
# Content:
# Opening Tag: author
# Content: Randall, Cynthia
# CLosing Tag: author
# Content:
#
# Content:
# Opening Tag: title
# Content: Lover Birds
# CLosing Tag: title
# Content:
#
# Content:
# Opening Tag: genre
# Content: Romance
# CLosing Tag: genre
# Content:
#
# Content:
# Opening Tag: price
# Content: 4.95
# CLosing Tag: price
# Content:
#
# Content:
# Opening Tag: publish_date
# Content: 2000-09-02
# CLosing Tag: publish_date
# Content:
#
# Content:
# Opening Tag: description
# Content: When Carla meets Paul at an ornithology
# Content:
#
# Content:       conference, tempers fly as feathers get ruffled.
# CLosing Tag: description
# Content:
#
# Content:
# CLosing Tag: book
# Content:
#
# Content:
# Opening Tag: book
# Content:
#
# Content:
# Opening Tag: author
# Content: Thurman, Paula
# CLosing Tag: author
# Content:
#
# Content:
# Opening Tag: title
# Content: Splish Splash
# CLosing Tag: title
# Content:
#
# Content:
# Opening Tag: genre
# Content: Romance
# CLosing Tag: genre
# Content:
#
# Content:
# Opening Tag: price
# Content: 4.95
# CLosing Tag: price
# Content:
#
# Content:
# Opening Tag: publish_date
# Content: 2000-11-02
# CLosing Tag: publish_date
# Content:
#
# Content:
# Opening Tag: description
# Content: A deep sea diver finds true love twenty
# Content:
#
# Content:       thousand leagues beneath the sea.
# CLosing Tag: description
# Content:
#
# Content:
# CLosing Tag: book
# Content:
#
# Content:
# Opening Tag: book
# Content:
#
# Content:
# Opening Tag: author
# Content: Knorr, Stefan
# CLosing Tag: author
# Content:
#
# Content:
# Opening Tag: title
# Content: Creepy Crawlies
# CLosing Tag: title
# Content:
#
# Content:
# Opening Tag: genre
# Content: Horror
# CLosing Tag: genre
# Content:
#
# Content:
# Opening Tag: price
# Content: 4.95
# CLosing Tag: price
# Content:
#
# Content:
# Opening Tag: publish_date
# Content: 2000-12-06
# CLosing Tag: publish_date
# Content:
#
# Content:
# Opening Tag: description
# Content: An anthology of horror stories about roaches,
# Content:
#
# Content:       centipedes, scorpions  and other insects.
# CLosing Tag: description
# Content:
#
# Content:
# CLosing Tag: book
# Content:
#
# Content:
# Opening Tag: book
# Content:
#
# Content:
# Opening Tag: author
# Content: Kress, Peter
# CLosing Tag: author
# Content:
#
# Content:
# Opening Tag: title
# Content: Paradox Lost
# CLosing Tag: title
# Content:
#
# Content:
# Opening Tag: genre
# Content: Science Fiction
# CLosing Tag: genre
# Content:
#
# Content:
# Opening Tag: price
# Content: 6.95
# CLosing Tag: price
# Content:
#
# Content:
# Opening Tag: publish_date
# Content: 2000-11-02
# CLosing Tag: publish_date
# Content:
#
# Content:
# Opening Tag: description
# Content: After an inadvertant trip through a Heisenberg
# Content:
#
# Content:       Uncertainty Device, James Salway discovers the problems
# Content:
#
# Content:       of being quantum.
# CLosing Tag: description
# Content:
#
# Content:
# CLosing Tag: book
# Content:
#
# Content:
# Opening Tag: book
# Content:
#
# Content:
# Opening Tag: author
# Content: O'Brien, Tim
# CLosing Tag: author
# Content:
#
# Content:
# Opening Tag: title
# Content: Microsoft .NET: The Programming Bible
# CLosing Tag: title
# Content:
#
# Content:
# Opening Tag: genre
# Content: Computer
# CLosing Tag: genre
# Content:
#
# Content:
# Opening Tag: price
# Content: 36.95
# CLosing Tag: price
# Content:
#
# Content:
# Opening Tag: publish_date
# Content: 2000-12-09
# CLosing Tag: publish_date
# Content:
#
# Content:
# Opening Tag: description
# Content: Microsoft's .NET initiative is explored in
# Content:
#
# Content:       detail in this deep programmer's reference.
# CLosing Tag: description
# Content:
#
# Content:
# CLosing Tag: book
# Content:
#
# Content:
# Opening Tag: book
# Content:
#
# Content:
# Opening Tag: author
# Content: O'Brien, Tim
# CLosing Tag: author
# Content:
#
# Content:
# Opening Tag: title
# Content: MSXML3: A Comprehensive Guide
# CLosing Tag: title
# Content:
#
# Content:
# Opening Tag: genre
# Content: Computer
# CLosing Tag: genre
# Content:
#
# Content:
# Opening Tag: price
# Content: 36.95
# CLosing Tag: price
# Content:
#
# Content:
# Opening Tag: publish_date
# Content: 2000-12-01
# CLosing Tag: publish_date
# Content:
#
# Content:
# Opening Tag: description
# Content: The Microsoft MSXML3 parser is covered in
# Content:
#
# Content:       detail, with attention to XML DOM interfaces, XSLT processing,
# Content:
#
# Content:       SAX and more.
# CLosing Tag: description
# Content:
#
# Content:
# CLosing Tag: book
# Content:
#
# Content:
# Opening Tag: book
# Content:
#
# Content:
# Opening Tag: author
# Content: Galos, Mike
# CLosing Tag: author
# Content:
#
# Content:
# Opening Tag: title
# Content: Visual Studio 7: A Comprehensive Guide
# CLosing Tag: title
# Content:
#
# Content:
# Opening Tag: genre
# Content: Computer
# CLosing Tag: genre
# Content:
#
# Content:
# Opening Tag: price
# Content: 49.95
# CLosing Tag: price
# Content:
#
# Content:
# Opening Tag: publish_date
# Content: 2001-04-16
# CLosing Tag: publish_date
# Content:
#
# Content:
# Opening Tag: description
# Content: Microsoft Visual Studio 7 is explored in depth,
# Content:
#
# Content:       looking at how Visual Basic, Visual C++, C#, and ASP+ are
# Content:
#
# Content:       integrated into a comprehensive development
# Content:
#
# Content:       environment.
# CLosing Tag: description
# Content:
#
# Content:
# CLosing Tag: book
# Content:
#
# CLosing Tag: catalog

# %%
class Handler(xml.sax.ContentHandler):
    """We must create our own handler which executues our desired code when the SAX
    parser parses an XML tag. In doing so, we must override existing methods."""

    def __init__(self):
        self.current_tag = None
        self.READfirst_tag = False

    def startElement(self, name, attrs):
        """The startElement method is called when the starting tag of an element is parsed.
        Here, we are overriding it with our own code."""

        if READfirst_tag is False:
            self.first_tag = name
            self.READfirst_tag = True

        

        
        
        print(f"Opening Tag: {name}")

    def endElement(self, name):
        """The endElement method is called when the end tag of an element is parsed. Here,
        we are overriding it with our own code."""
        print(f"Closing Tag: {name}")

    def characters(self, content):
        print(f"Content: {content}")

# We create our handler object,
handler = Handler()

# Then we create our SAX parser and set its handler,
parser = xml.sax.make_parser()
parser.setContentHandler(handler)

# Finally, we must called the
